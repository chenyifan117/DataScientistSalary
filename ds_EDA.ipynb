# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

pd.set_option('display.max_rows', None)

# %%
df = pd.read_csv('cleaned_ds_job.csv')
df.head()
# Out:
#                            company  \
# 0           Oasis Systems LLC\n4.4
# 1   American Family Insurance\n3.2
# 2  Scottish Rite for Children\n3.9
# 3            Northrop Grumman\n4.0
# 4                  Cirkul Inc\n3.4
#
#                                            job title           location  \
# 0                       Senior Python Data Scientist     Washington, DC
# 1  Principal Data Scientist - Personal Lines, Aut...        Madison, WI
# 2                     Senior Healthcare Data Analyst         Dallas, TX
# 3                           Principal Data Scientist  Redondo Beach, CA
# 4                                Lead Data Scientist      Watertown, MA
#
#                                      job description  \
# 0  Overview:\nOasis Systems has an exciting oppor...
# 1  At American Family Insurance, we believe peopl...
# 2  Our patients are our number one priority! We'r...
# 3  Requisition ID: R10086374\nCategory: Research ...
# ...

# %%
# jd length
df['jd_len'] = df['job description'].apply(lambda x: len(x))

# %%
df.columns
# Out:
# Index(['company', 'job title', 'location', 'job description',
#        'salary estimate', 'company_size', 'company_type', 'company_sector',
#        'company_industry', 'company_founded', 'company_revenue', 'company_txt',
#        'without_rating', 'rating', 'without_city', 'state', 'python', 'hadoop',
#        'spark', 'tableau', 'tensorflow', 'aws', 'excel', 'hourly',
#        'min_salary', 'max_salary', 'avg_salary', 'age', 'simp_title', 'rank',
#        'jd_len'],
#       dtype='object')

# %%
df_contin = df[['rating', 'avg_salary', 'age', 'jd_len']]
df_contin.hist()
# Out:
# array([[<AxesSubplot:title={'center':'rating'}>,
#         <AxesSubplot:title={'center':'avg_salary'}>],
#        [<AxesSubplot:title={'center':'age'}>,
#         <AxesSubplot:title={'center':'jd_len'}>]], dtype=object)

# %%
df.boxplot(column='jd_len')
# Out:
# <AxesSubplot:>

# %%
df[['avg_salary', 'age']].boxplot()
# Out:
# <AxesSubplot:>

# %%
df.boxplot(column='rating')
# Out:
# <AxesSubplot:>

# %%
df_contin.corr()
# Out:
#               rating  avg_salary       age    jd_len
# rating      1.000000   -0.069418 -0.092640  0.110545
# avg_salary -0.069418    1.000000 -0.002818  0.225642
# age        -0.092640   -0.002818  1.000000  0.453666
# jd_len      0.110545    0.225642  0.453666  1.000000

# %%
cmap = sns.diverging_palette(220, 10, as_cmap=True)
sns.heatmap(df_contin.corr(), cmap=cmap)
plt.show()

# %%
df.columns
# Out:
# Index(['company', 'job title', 'location', 'job description',
#        'salary estimate', 'company_size', 'company_type', 'company_sector',
#        'company_industry', 'company_founded', 'company_revenue', 'company_txt',
#        'without_rating', 'rating', 'without_city', 'state', 'python', 'hadoop',
#        'spark', 'tableau', 'tensorflow', 'aws', 'excel', 'hourly',
#        'min_salary', 'max_salary', 'avg_salary', 'age', 'simp_title', 'rank',
#        'jd_len'],
#       dtype='object')

# %%
df_cat = df[['location', 'company_size', 'company_type', 'company_sector', 'company_industry','company_revenue','company_txt','state','simp_title','rank','python','hadoop','spark','tableau','tensorflow','aws','excel','hourly']]

# %%
df_cat['location'].value_counts().index
# Out:
# Index(['Hartford, CT', 'Santa Clara, CA', 'Washington, DC', 'Morrisville, NC',
#        'Beavercreek, OH', 'Vienna, VA', 'Columbia, MD', 'Madison, WI',
#        'Roy, UT', 'La Grange, IL', 'Arlington, VA', 'Palmdale, CA',
#        'Watertown, MA', 'Dallas, TX', 'Wyoming', 'Danvers, MA',
#        'Palo Alto, CA', 'Lexington, MA', 'Seatac, WA', 'Cranbury, NJ',
#        'Fort Meade, MD', 'Redondo Beach, CA', 'Remote', 'Rosslyn, VA',
#        'McLean, VA', 'Irving, TX', 'Princeton, NJ', 'Annapolis Junction, MD',
#        'Boston, MA', 'Bethesda, MD', 'Somerville, MA',
#        'South San Francisco, CA', 'Chicago, IL', 'San Diego, CA',
#        'Sunnyvale, CA', 'Cambridge, MA', 'Fairfield, CT', 'Kansas City, MO',
#        'Chevy Chase, MD', 'Silver Spring, MD', 'Philadelphia, PA',
#        'New York, NY', 'Los Angeles, CA', 'Wilmington, NC', 'Portland, ME',
#        'Reston, VA', 'Riverwoods, IL', 'Jacksonville, FL', 'Ann Arbor, MI',
# ...

# %%
ax = sns.barplot(x=df_cat['location'].value_counts().index, y=df_cat['location'].value_counts())
ax.set_xticklabels(ax.get_xmajorticklabels(), fontsize = 8)
plt.xticks(rotation=90)
plt.show()

# %%
for col in df_cat.columns:
    ax = sns.barplot(x=df_cat[col].value_counts().index, y=df_cat[col].value_counts())
    ax.set_xticklabels(ax.get_xmajorticklabels(), fontsize = 8)
    plt.xticks(rotation=90)
    plt.show()

# %%
pd.pivot_table(df, index=['simp_title','rank'], values='avg_salary')
# Out:
#                                     avg_salary
# simp_title                rank
# data analyst              director  100.000000
#                           na         92.761905
#                           senior    106.657407
# data engineer             na        128.967742
#                           senior    139.500000
# data scientist            director  139.400000
#                           junior     70.000000
#                           na        120.663462
#                           senior    171.500000
# machine learning engineer junior     76.000000
#                           na        102.210526
#                           senior    242.245283
# na                        director  191.250000
#                           na        136.500000
#                           senior    141.386792

# %%
pd.pivot_table(df, index=['simp_title','rank'], values='avg_salary', aggfunc = 'count')
# Out:
#                                     avg_salary
# simp_title                rank
# data analyst              director           8
#                           na                21
#                           senior            54
# data engineer             na                31
#                           senior             2
# data scientist            director           5
#                           junior             4
#                           na                52
#                           senior           177
# machine learning engineer junior             1
#                           na                38
#                           senior            53
# na                        director          40
#                           na                45
#                           senior           106

# %%
pd.pivot_table(df, index = 'location', values = 'avg_salary').sort_values('avg_salary', ascending=False)
# Out:
#                          avg_salary
# location
# Madison, WI              300.000000
# Santa Clara, CA          269.607843
# Palmdale, CA             250.000000
# Redondo Beach, CA        233.333333
# Palo Alto, CA            231.578947
# Columbia, MD             200.000000
# Sunnyvale, CA            200.000000
# Englewood, CO            150.000000
# Roy, UT                  150.000000
# Hartford, CT             150.000000
# Seatac, WA               150.000000
# Boulder, CO              150.000000
# Cambridge, MA            150.000000
# Beavercreek, OH          150.000000
# Watertown, MA            150.000000
# Philadelphia, NY         150.000000
# San Jose, CA             150.000000
# South San Francisco, CA  150.000000
# San Diego, CA            149.000000
# Morrisville, NC          147.522727
# Lexington, MA            147.222222
# Fort Meade, MD           145.833333
# Vienna, VA               145.214286
# Remote                   136.727273
# Bethesda, MD             136.200000
# ...

# %%
pd.pivot_table(df, index = 'state', values = 'avg_salary').sort_values('avg_salary', ascending=False)
# Out:
#           avg_salary
# state
#  WI       300.000000
#  CA       242.504348
#  MD       153.330189
#  WA       150.000000
#  UT       150.000000
#  OH       150.000000
#  CO       150.000000
#  CT       147.071429
#  NC       140.740000
# Remote    136.727273
#  MA       129.595890
#  ME       122.250000
#  MO       113.000000
#  VA       109.126984
#  NY       107.333333
#  PA       105.833333
# Maryland  100.000000
#  IL        98.115385
#  DC        93.812500
#  RI        93.000000
#  MN        92.500000
#  NJ        91.777778
#  GA        90.000000
#  FL        90.000000
# Wyoming    87.052632
#  TX        85.189655
#  MI        68.000000

# %%
pd.pivot_table(df, index = 'state', values = 'avg_salary', aggfunc='count').sort_values('avg_salary', ascending=False)
# Out:
#           avg_salary
# state
#  CA              115
#  MA               73
#  CT               63
#  VA               63
#  MD               53
#  DC               32
#  TX               29
#  NJ               27
#  IL               26
#  NC               25
#  OH               21
#  WI               20
#  UT               20
# Wyoming           19
#  WA               18
# Remote            11
#  FL                4
#  MO                3
#  NY                3
#  PA                3
#  CO                2
#  ME                2
# Maryland           1
#  MI                1
#  GA                1
#  MN                1
#  RI                1

# %%
pd.pivot_table(df, index = ['state','simp_title'], values = 'avg_salary', aggfunc='count')
# Out:
#                                     avg_salary
# state    simp_title
#  CA      data engineer                       1
#          data scientist                     32
#          machine learning engineer          50
#          na                                 32
#  CO      machine learning engineer           1
#          na                                  1
#  CT      data engineer                      20
#          na                                 43
#  DC      data analyst                        8
#          data scientist                     24
#  FL      data analyst                        1
#          data scientist                      2
#          na                                  1
#  GA      data analyst                        1
#  IL      data analyst                       20
#          data scientist                      5
#          na                                  1
#  MA      data analyst                        2
# ...

# %%
df_pivot = df[['location', 'company_size', 'company_type', 'company_sector', 'company_industry','company_revenue','company_txt','state','simp_title','rank','python','hadoop','spark','tableau','tensorflow','aws','excel','hourly','avg_salary']]

# %%
df_pivot.columns[:-1]
# Out:
# Index(['location', 'company_size', 'company_type', 'company_sector',
#        'company_industry', 'company_revenue', 'company_txt', 'state',
#        'simp_title', 'rank', 'python', 'hadoop', 'spark', 'tableau',
#        'tensorflow', 'aws', 'excel', 'hourly'],
#       dtype='object')

# %%
for i in df_pivot.columns[:-1]:
    print('-------------------')
    print(i, ' ~ mean avg_salary')
    print(pd.pivot_table(df, index = i, values = 'avg_salary').sort_values('avg_salary', ascending=False))
# Out:
# -------------------
# location  ~ mean avg_salary
#                          avg_salary
# location
# Madison, WI              300.000000
# Santa Clara, CA          269.607843
# Palmdale, CA             250.000000
# Redondo Beach, CA        233.333333
# Palo Alto, CA            231.578947
# Columbia, MD             200.000000
# Sunnyvale, CA            200.000000
# Englewood, CO            150.000000
# Roy, UT                  150.000000
# Hartford, CT             150.000000
# Seatac, WA               150.000000
# Boulder, CO              150.000000
# Cambridge, MA            150.000000
# Beavercreek, OH          150.000000
# Watertown, MA            150.000000
# Philadelphia, NY         150.000000
# San Jose, CA             150.000000
# South San Francisco, CA  150.000000
# San Diego, CA            149.000000
# Morrisville, NC          147.522727
# Lexington, MA            147.222222
# Fort Meade, MD           145.833333
# Vienna, VA               145.214286
# ...

# %%
# word cloud for job description
from wordcloud import WordCloud, ImageColorGenerator, STOPWORDS
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# %%
words = " ".join(df['job description'])

def punctuation_stop(text):
    """remove punctuation and stop words"""
    filtered = []
    stop_words = set(stopwords.words('english'))
    word_tokens = word_tokenize(text)
    for w in word_tokens:
        if w not in stop_words and w.isalpha():
            filtered.append(w.lower())
    return filtered


words_filtered = punctuation_stop(words)

text = " ".join([ele for ele in words_filtered])

wc= WordCloud(background_color="white", random_state=1,stopwords=STOPWORDS, max_words = 2000, width =800, height = 1500)
wc.generate(text)

plt.figure(figsize=[10,10])
plt.imshow(wc, interpolation="bilinear")
plt.axis('off')
plt.show()
